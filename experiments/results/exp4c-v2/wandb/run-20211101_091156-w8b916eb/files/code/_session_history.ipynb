# %%
from fastai.tabular.all import *
from transfertab.utils import *
from transfertab.transfer import *
from transfertab.extract import *
from fastcore.xtras import *
from fastai.learner import *
import torch
import numpy as np
from fastai.interpret import *

# %%
import pandas as pd
df = pd.read_csv("../data/bank-additional-full.csv", delimiter=';')

# %%
import wandb
from fastai.callback.wandb import *

# %%
df.shape
# Out:
# (41188, 21)

# %%
41188 * 0.7
# Out:
# 28831.6

# %%
dfA = df.iloc[0:28831]
dfB = df.iloc[28831:-1]

# %%
dfA.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
contcols = ['age', 'duration', 'campaign', 'pdays',
       'previous', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed']
catcols = ['job', 'marital', 'education', 'default', 'housing', 'loan','contact', 
	'month', 'day_of_week','poutcome']
target = 'y'

# %%
splitsA = RandomSplitter(valid_pct=0.2)(range_of(dfA))
toA = TabularPandas(dfA, procs=[Categorify, FillMissing, Normalize],
                   cat_names=catcols,
                   cont_names=contcols,
                   y_names=target,
                   splits=splitsA)
dlsA = toA.dataloaders(bs=512)
learnA = tabular_learner(dlsA, metrics=RocAucBinary)

# %%
splitsA = RandomSplitter(valid_pct=0.2)(range_of(dfA))
toA = TabularPandas(dfA, procs=[Categorify, FillMissing, Normalize],
                   cat_names=catcols,
                   cont_names=contcols,
                   y_names=target,
                   splits=splitsA)
dlsA = toA.dataloaders(bs=512)
rocaucbin = RocAucBinary()
learnA = tabular_learner(dlsA, metrics=[rocaucbin, accuracy])

# %%
wandb.init(
    project='Experiments', 
    save_code=True, 
    group='Exp4c v2', 
    job_type='pretrain', 
    tags=['base', 'bank', 'modelA'], 
    name='modelA training',
    notes="Training modelA from which we'll take embeddings",
    reinit=True,
    dir='/Users/manikyabardhan/Documents/github/transfertab/results/exp4c-v2',
    entity='transfertab'
)
# Out:
# <wandb.sdk.wandb_run.Run at 0x7ff9f7d7b700>

# %%
cbs=[WandbCallback(log="all", dataset_name="bank-additional-full (first .7)", n_preds=128, seed=1), SaveModelCallback()]
learnA.fit_one_cycle(50, cbs=cbs)

# %%
learnA.recorder.plot_loss()

# %%
torch.save(learnA.model.state_dict(),"results/modelA_state_dict")

# %%
torch.save(learnA.model.state_dict(),"../results/modelA_state_dict")

# %%
torch.save(learnA.model.state_dict(),"../results/exp4c-v2/modelA_state_dict")

# %%
catdict = {col:list(learnA.dls.categorify.classes[col]) for col in catcols}

# %%
embeds = extractembeds(learnA.model, catdict, transfercats=catcols, allcats=catcols, path="learnA_extracts", kind="json")

# %%
wandb.finish()

# %%
splitsB = RandomSplitter(valid_pct=0.2)(range_of(dfB))
toB = TabularPandas(dfB, procs=[Categorify, FillMissing, Normalize],
                   cat_names = catcols,
                   cont_names = contcols,
                   y_names=target,
                   splits=splitsB)
dlsB = toB.dataloaders(bs=512)

# %%
learnB = tabular_learner(dlsB, metrics=accuracy, emb_szs={'default':4, 'month':12})

# %%
# catdict = getcatdict(df, catcols)
metadict = {}
for (cat, classes) in catdict.items():
	metadict[cat] = {'mapped_cat': cat, 'classes_info': {clas: clas for clas in classes}}
with open('bank_meta.json', 'w') as fp:
	json.dump(metadict, fp)

# %%
with open('data/json/bank_meta.json', 'r') as fp:
    metadict = json.load(fp)

# %%
with open('../data/json/bank_meta.json', 'r') as fp:
    metadict = json.load(fp)

# %%
with open('../data/jsons/bank_meta.json', 'r') as fp:
    metadict = json.load(fp)

# %%
metadict
# Out:
# {'job': {'mapped_cat': 'job',
#   'classes_info': {'#na#': '#na#',
#    'admin.': 'admin.',
#    'blue-collar': 'blue-collar',
#    'entrepreneur': 'entrepreneur',
#    'housemaid': 'housemaid',
#    'management': 'management',
#    'retired': 'retired',
#    'self-employed': 'self-employed',
#    'services': 'services',
#    'student': 'student',
#    'technician': 'technician',
#    'unemployed': 'unemployed',
#    'unknown': 'unknown'}},
#  'marital': {'mapped_cat': 'marital',
#   'classes_info': {'#na#': '#na#',
#    'divorced': 'divorced',
#    'married': 'married',
#    'single': 'single',
#    'unknown': 'unknown'}},
#  'education': {'mapped_cat': 'education',
#   'classes_info': {'#na#': '#na#',
#    'basic.4y': 'basic.4y',
#    'basic.6y': 'basic.6y',
#    'basic.9y': 'basic.9y',
#    'high.school': 'high.school',
#    'illiterate': 'illiterate',
#    'professional.course': 'professional.course',
#    'university.degree': 'university.degree',
#    'unknown': 'unknown'}},
#  'default': {'mapped_cat': 'default',
#   'classes_info': {'#na#': '#na#', 'no': 'no', 'unknown': 'unknown'}},
#  'housing': {'mapped_cat': 'housing',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'loan': {'mapped_cat': 'loan',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'contact': {'mapped_cat': 'contact',
#   'classes_info': {'#na#': '#na#',
#    'cellular': 'cellular',
#    'telephone': 'telephone'}},
#  'month': {'mapped_cat': 'month',
#   'classes_info': {'#na#': '#na#',
#    'apr': 'apr',
#    'aug': 'aug',
#    'dec': 'dec',
#    'jul': 'jul',
#    'jun': 'jun',
#    'mar': 'mar',
#    'may': 'may',
#    'nov': 'nov',
#    'oct': 'oct',
#    'sep': []}},
#  'day_of_week': {'mapped_cat': 'day_of_week',
#   'classes_info': {'#na#': '#na#',
#    'fri': 'fri',
#    'mon': 'mon',
#    'thu': 'thu',
#    'tue': 'tue',
#    'wed': 'wed'}},
#  'poutcome': {'mapped_cat': 'poutcome',
#   'classes_info': {'#na#': '#na#',
#    'failure': 'failure',
#    'nonexistent': 'nonexistent',
#    'success': 'success'}}}

# %%
learnB.dls.categorify['month']
# Out:
# ['#na#', 'apr', 'aug', 'dec', 'jul', 'jun', 'mar', 'may', 'nov', 'oct', 'sep']

# %%
learnA.dls.categorify['month']
# Out:
# ['#na#', 'apr', 'aug', 'dec', 'jul', 'jun', 'mar', 'may', 'nov', 'oct']

# %%
learnB.model.embeds
# Out:
# ModuleList(
#   (0): Embedding(13, 7)
#   (1): Embedding(5, 4)
#   (2): Embedding(9, 5)
#   (3): Embedding(3, 4)
#   (4): Embedding(4, 3)
#   (5): Embedding(4, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(11, 12)
#   (8): Embedding(6, 4)
#   (9): Embedding(4, 3)
# )

# %%
learnB.dls.cat_names
# Out:
# (#10) ['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']

# %%
catcols
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
learnA.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown', 'yes']

# %%
learnB.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown']

# %%
transfercats = ['job',
 'marital',
 'education',
#  'default',
 'housing',
 'loan',
 'contact',
 'month',
 'day_of_week',
 'poutcome']

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdict, 
    newcatdict=catdict)

# %%
transfercats = ['job',
 'marital',
 'education',
#  'default',
 'housing',
 'loan',
 'contact',
#  'month',
 'day_of_week',
 'poutcome']

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdict, 
    newcatdict=catdict)

# %%
transfercats = ['job',
 'marital',
 'education',
#  'default',
 'housing',
 'loan',
 'contact',
 'month',
 'day_of_week',
 'poutcome']

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdict, 
    newcatdict=catdict)

# %%
learnB = tabular_learner(dlsB, metrics=accuracy, emb_szs={'month':6})

# %%
# catdict = getcatdict(df, catcols)
# metadict = {}
# for (cat, classes) in catdict.items():
# 	metadict[cat] = {'mapped_cat': cat, 'classes_info': {clas: clas for clas in classes}}
# with open('bank_meta.json', 'w') as fp:
# 	json.dump(metadict, fp)

# %%
# metadict={"job": {"mapped_cat": "job", "classes_info": {"#na#": "#na#", "admin.": "admin.", "blue-collar": "blue-collar", "entrepreneur": "entrepreneur", "housemaid": "housemaid", "management": "management", "retired": "retired", "self-employed": "self-employed", "services": "services", "student": "student", "technician": "technician", "unemployed": "unemployed", "unknown": "unknown"}}, "marital": {"mapped_cat": "marital", "classes_info": {"#na#": "#na#", "divorced": "divorced", "married": "married", "single": "single", "unknown": "unknown"}}, "education": {"mapped_cat": "education", "classes_info": {"#na#": "#na#", "basic.4y": "basic.4y", "basic.6y": "basic.6y", "basic.9y": "basic.9y", "high.school": "high.school", "illiterate": "illiterate", "professional.course": "professional.course", "university.degree": "university.degree", "unknown": "unknown"}}, "default": {"mapped_cat": "default", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown"}}, "housing": {"mapped_cat": "housing", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown", "yes": "yes"}}, "loan": {"mapped_cat": "loan", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown", "yes": "yes"}}, "contact": {"mapped_cat": "contact", "classes_info": {"#na#": "#na#", "cellular": "cellular", "telephone": "telephone"}}, "month": {"mapped_cat": "month", "classes_info": {"#na#": "#na#", "apr": "apr", "aug": "aug", "dec": "dec", "jul": "jul", "jun": "jun", "mar": "mar", "may": "may", "nov": "nov", "oct": "oct", "sep":[]}}, "day_of_week": {"mapped_cat": "day_of_week", "classes_info": {"#na#": "#na#", "fri": "fri", "mon": "mon", "thu": "thu", "tue": "tue", "wed": "wed"}}, "poutcome": {"mapped_cat": "poutcome", "classes_info": {"#na#": "#na#", "failure": "failure", "nonexistent": "nonexistent", "success": "success"}}}

# %%
with open('../data/jsons/bank_meta.json', 'r') as fp:
    metadict = json.load(fp)

# %%
metadict
# Out:
# {'job': {'mapped_cat': 'job',
#   'classes_info': {'#na#': '#na#',
#    'admin.': 'admin.',
#    'blue-collar': 'blue-collar',
#    'entrepreneur': 'entrepreneur',
#    'housemaid': 'housemaid',
#    'management': 'management',
#    'retired': 'retired',
#    'self-employed': 'self-employed',
#    'services': 'services',
#    'student': 'student',
#    'technician': 'technician',
#    'unemployed': 'unemployed',
#    'unknown': 'unknown'}},
#  'marital': {'mapped_cat': 'marital',
#   'classes_info': {'#na#': '#na#',
#    'divorced': 'divorced',
#    'married': 'married',
#    'single': 'single',
#    'unknown': 'unknown'}},
#  'education': {'mapped_cat': 'education',
#   'classes_info': {'#na#': '#na#',
#    'basic.4y': 'basic.4y',
#    'basic.6y': 'basic.6y',
#    'basic.9y': 'basic.9y',
#    'high.school': 'high.school',
#    'illiterate': 'illiterate',
#    'professional.course': 'professional.course',
#    'university.degree': 'university.degree',
#    'unknown': 'unknown'}},
#  'default': {'mapped_cat': 'default',
#   'classes_info': {'#na#': '#na#', 'no': 'no', 'unknown': 'unknown'}},
#  'housing': {'mapped_cat': 'housing',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'loan': {'mapped_cat': 'loan',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'contact': {'mapped_cat': 'contact',
#   'classes_info': {'#na#': '#na#',
#    'cellular': 'cellular',
#    'telephone': 'telephone'}},
#  'month': {'mapped_cat': 'month',
#   'classes_info': {'#na#': '#na#',
#    'apr': 'apr',
#    'aug': 'aug',
#    'dec': 'dec',
#    'jul': 'jul',
#    'jun': 'jun',
#    'mar': 'mar',
#    'may': 'may',
#    'nov': 'nov',
#    'oct': 'oct',
#    'sep': []}},
#  'day_of_week': {'mapped_cat': 'day_of_week',
#   'classes_info': {'#na#': '#na#',
#    'fri': 'fri',
#    'mon': 'mon',
#    'thu': 'thu',
#    'tue': 'tue',
#    'wed': 'wed'}},
#  'poutcome': {'mapped_cat': 'poutcome',
#   'classes_info': {'#na#': '#na#',
#    'failure': 'failure',
#    'nonexistent': 'nonexistent',
#    'success': 'success'}}}

# %%
learnB.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown']

# %%
learnA.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown', 'yes']

# %%
learnA.model.embeds
# Out:
# ModuleList(
#   (0): Embedding(13, 7)
#   (1): Embedding(5, 4)
#   (2): Embedding(9, 5)
#   (3): Embedding(4, 3)
#   (4): Embedding(4, 3)
#   (5): Embedding(4, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(10, 6)
#   (8): Embedding(6, 4)
#   (9): Embedding(4, 3)
# )

# %%
learnB.model.embeds
# Out:
# ModuleList(
#   (0): Embedding(13, 7)
#   (1): Embedding(5, 4)
#   (2): Embedding(9, 5)
#   (3): Embedding(3, 3)
#   (4): Embedding(4, 3)
#   (5): Embedding(4, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(11, 6)
#   (8): Embedding(6, 4)
#   (9): Embedding(4, 3)
# )

# %%
learnB.dls.cat_names
# Out:
# (#10) ['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']

# %%
transfercats = ['job',
 'marital',
 'education',
#  'default',
 'housing',
 'loan',
 'contact',
 'month',
 'day_of_week',
 'poutcome']

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdict, 
    newcatdict=catdict)

# %%
catdictA = {col:list(learnA.dls.categorify.classes[col]) for col in catcols}

# %%
catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcols}

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdictA, 
    newcatdict=catdictB)

# %%
transfercats = ['job',
 'marital',
 'education',
 'default',
 'housing',
 'loan',
 'contact',
 'month',
 'day_of_week',
 'poutcome']

# %%
catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcols}

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdictA, 
    newcatdict=catdictB)

# %%
learnA.model.embeds[catcols.index('marital')].weight
# Out:
# Parameter containing:
# tensor([[-0.0041,  0.0100,  0.0102, -0.0024],
#         [ 0.0009,  0.0190,  0.0418,  0.0202],
#         [-0.0319,  0.0140, -0.0415, -0.0403],
#         [ 0.0654, -0.0346, -0.0149,  0.0547],
#         [-0.0699, -0.0018, -0.0980,  0.0875]], requires_grad=True)

# %%
learnB.model.embeds[catcols.index('marital')].weight
# Out:
# Parameter containing:
# tensor([[-0.0041,  0.0100,  0.0102, -0.0024],
#         [ 0.0009,  0.0190,  0.0418,  0.0202],
#         [-0.0319,  0.0140, -0.0415, -0.0403],
#         [ 0.0654, -0.0346, -0.0149,  0.0547],
#         [-0.0699, -0.0018, -0.0980,  0.0875]], requires_grad=True)

# %%
rocaucbinB = RocAucBinary()
learnB = tabular_learner(dlsB, metrics=[rocaucbinB, accuracy], emb_szs={'month':6})

# %%
# catdict = getcatdict(df, catcols)
# metadict = {}
# for (cat, classes) in catdict.items():
# 	metadict[cat] = {'mapped_cat': cat, 'classes_info': {clas: clas for clas in classes}}
# with open('bank_meta.json', 'w') as fp:
# 	json.dump(metadict, fp)

# %%
# metadict={"job": {"mapped_cat": "job", "classes_info": {"#na#": "#na#", "admin.": "admin.", "blue-collar": "blue-collar", "entrepreneur": "entrepreneur", "housemaid": "housemaid", "management": "management", "retired": "retired", "self-employed": "self-employed", "services": "services", "student": "student", "technician": "technician", "unemployed": "unemployed", "unknown": "unknown"}}, "marital": {"mapped_cat": "marital", "classes_info": {"#na#": "#na#", "divorced": "divorced", "married": "married", "single": "single", "unknown": "unknown"}}, "education": {"mapped_cat": "education", "classes_info": {"#na#": "#na#", "basic.4y": "basic.4y", "basic.6y": "basic.6y", "basic.9y": "basic.9y", "high.school": "high.school", "illiterate": "illiterate", "professional.course": "professional.course", "university.degree": "university.degree", "unknown": "unknown"}}, "default": {"mapped_cat": "default", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown"}}, "housing": {"mapped_cat": "housing", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown", "yes": "yes"}}, "loan": {"mapped_cat": "loan", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown", "yes": "yes"}}, "contact": {"mapped_cat": "contact", "classes_info": {"#na#": "#na#", "cellular": "cellular", "telephone": "telephone"}}, "month": {"mapped_cat": "month", "classes_info": {"#na#": "#na#", "apr": "apr", "aug": "aug", "dec": "dec", "jul": "jul", "jun": "jun", "mar": "mar", "may": "may", "nov": "nov", "oct": "oct", "sep":[]}}, "day_of_week": {"mapped_cat": "day_of_week", "classes_info": {"#na#": "#na#", "fri": "fri", "mon": "mon", "thu": "thu", "tue": "tue", "wed": "wed"}}, "poutcome": {"mapped_cat": "poutcome", "classes_info": {"#na#": "#na#", "failure": "failure", "nonexistent": "nonexistent", "success": "success"}}}

# %%
with open('../data/jsons/bank_meta.json', 'r') as fp:
    metadict = json.load(fp)

# %%
metadict
# Out:
# {'job': {'mapped_cat': 'job',
#   'classes_info': {'#na#': '#na#',
#    'admin.': 'admin.',
#    'blue-collar': 'blue-collar',
#    'entrepreneur': 'entrepreneur',
#    'housemaid': 'housemaid',
#    'management': 'management',
#    'retired': 'retired',
#    'self-employed': 'self-employed',
#    'services': 'services',
#    'student': 'student',
#    'technician': 'technician',
#    'unemployed': 'unemployed',
#    'unknown': 'unknown'}},
#  'marital': {'mapped_cat': 'marital',
#   'classes_info': {'#na#': '#na#',
#    'divorced': 'divorced',
#    'married': 'married',
#    'single': 'single',
#    'unknown': 'unknown'}},
#  'education': {'mapped_cat': 'education',
#   'classes_info': {'#na#': '#na#',
#    'basic.4y': 'basic.4y',
#    'basic.6y': 'basic.6y',
#    'basic.9y': 'basic.9y',
#    'high.school': 'high.school',
#    'illiterate': 'illiterate',
#    'professional.course': 'professional.course',
#    'university.degree': 'university.degree',
#    'unknown': 'unknown'}},
#  'default': {'mapped_cat': 'default',
#   'classes_info': {'#na#': '#na#', 'no': 'no', 'unknown': 'unknown'}},
#  'housing': {'mapped_cat': 'housing',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'loan': {'mapped_cat': 'loan',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'contact': {'mapped_cat': 'contact',
#   'classes_info': {'#na#': '#na#',
#    'cellular': 'cellular',
#    'telephone': 'telephone'}},
#  'month': {'mapped_cat': 'month',
#   'classes_info': {'#na#': '#na#',
#    'apr': 'apr',
#    'aug': 'aug',
#    'dec': 'dec',
#    'jul': 'jul',
#    'jun': 'jun',
#    'mar': 'mar',
#    'may': 'may',
#    'nov': 'nov',
#    'oct': 'oct',
#    'sep': []}},
#  'day_of_week': {'mapped_cat': 'day_of_week',
#   'classes_info': {'#na#': '#na#',
#    'fri': 'fri',
#    'mon': 'mon',
#    'thu': 'thu',
#    'tue': 'tue',
#    'wed': 'wed'}},
#  'poutcome': {'mapped_cat': 'poutcome',
#   'classes_info': {'#na#': '#na#',
#    'failure': 'failure',
#    'nonexistent': 'nonexistent',
#    'success': 'success'}}}

# %%
learnB.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown']

# %%
learnA.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown', 'yes']

# %%
learnA.model.embeds
# Out:
# ModuleList(
#   (0): Embedding(13, 7)
#   (1): Embedding(5, 4)
#   (2): Embedding(9, 5)
#   (3): Embedding(4, 3)
#   (4): Embedding(4, 3)
#   (5): Embedding(4, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(10, 6)
#   (8): Embedding(6, 4)
#   (9): Embedding(4, 3)
# )

# %%
learnB.model.embeds
# Out:
# ModuleList(
#   (0): Embedding(13, 7)
#   (1): Embedding(5, 4)
#   (2): Embedding(9, 5)
#   (3): Embedding(3, 3)
#   (4): Embedding(4, 3)
#   (5): Embedding(4, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(11, 6)
#   (8): Embedding(6, 4)
#   (9): Embedding(4, 3)
# )

# %%
learnB.dls.cat_names
# Out:
# (#10) ['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']

# %%
transfercats = ['job',
 'marital',
 'education',
 'default',
 'housing',
 'loan',
 'contact',
 'month',
 'day_of_week',
 'poutcome']

# %%
catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcols}

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdictA, 
    newcatdict=catdictB)

# %%
learnA.model.embeds[catcols.index('marital')].weight
# Out:
# Parameter containing:
# tensor([[-0.0041,  0.0100,  0.0102, -0.0024],
#         [ 0.0009,  0.0190,  0.0418,  0.0202],
#         [-0.0319,  0.0140, -0.0415, -0.0403],
#         [ 0.0654, -0.0346, -0.0149,  0.0547],
#         [-0.0699, -0.0018, -0.0980,  0.0875]], requires_grad=True)

# %%
learnB.model.embeds[catcols.index('marital')].weight
# Out:
# Parameter containing:
# tensor([[-0.0041,  0.0100,  0.0102, -0.0024],
#         [ 0.0009,  0.0190,  0.0418,  0.0202],
#         [-0.0319,  0.0140, -0.0415, -0.0403],
#         [ 0.0654, -0.0346, -0.0149,  0.0547],
#         [-0.0699, -0.0018, -0.0980,  0.0875]], requires_grad=True)

# %%
dlsC = deepcopy(dlsB)
rocaucbinC = RocAucBinary()
learnC = tabular_learner(dlsC, metrics=[rocaucbinC, accuracy], emb_szs={'month':6})

# %%
learnC.model.layers.load_state_dict(learnB.model.layers.state_dict())
# Out:
# <All keys matched successfully>

# %%
wandb.init(
    project='Experiments',
    entity='transfertab',
    save_code=True, 
    group='Exp4c v2', 
    job_type='finetune', 
    tags=['transfer', 'bank', 'modelB'], 
    name='modelB training',
    notes='Training modelB which contains transferred embeddings',
    reinit=True,
    dir='/Users/manikyabardhan/Documents/github/transfertab/results/exp4c-v2'
)
# Out:
# <wandb.sdk.wandb_run.Run at 0x7ff9fbb66040>

# %%
for i in range(len(catcols)):
    learnB.model.embeds[i].weight.requires_grad = False
learnB.create_opt()

# %%
learnB.embeds[5].weight
# Out:
# Parameter containing:
# tensor([[ 0.0012, -0.0142, -0.0104],
#         [-0.0150,  0.0564, -0.0425],
#         [-0.0274,  0.0058, -0.0065],
#         [ 0.0386, -0.0425,  0.0627]])

# %%
cbsB=[WandbCallback(log="all", dataset_name="bank 0.3%", n_preds=128, seed=1), SaveModelCallback()]
learnB.fit_one_cycle(3, cbs=cbsB)

# %%
wandb.finish()

# %%
wandb.init(
    project='Experiments',
    entity='transfertab',
    save_code=True, 
    group='Exp4c v2', 
    job_type='finetune', 
    tags=['transfer', 'bank', 'modelB'], 
    name='modelB training',
    notes='Training modelB which contains transferred embeddings',
    reinit=True,
    dir='/Users/manikyabardhan/Documents/github/transfertab/results/exp4c-v2'
)
# Out:
# <wandb.sdk.wandb_run.Run at 0x7ff9f9c2c910>
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">modelB training</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/transfertab/Experiments" target="_blank">https://wandb.ai/transfertab/Experiments</a><br/>
#                 Run page: <a href="https://wandb.ai/transfertab/Experiments/runs/w8b916eb" target="_blank">https://wandb.ai/transfertab/Experiments/runs/w8b916eb</a><br/>
#                 Run data is saved locally in <code>/Users/manikyabardhan/Documents/github/transfertab/results/exp4c-v2/wandb/run-20211101_091156-w8b916eb</code><br/><br/>

# %%
splitsB = RandomSplitter(valid_pct=0.2)(range_of(dfB))
toB = TabularPandas(dfB, procs=[Categorify, FillMissing, Normalize],
                   cat_names = catcols,
                   cont_names = contcols,
                   y_names=target,
                   splits=splitsB)
dlsB = toB.dataloaders(bs=512)

# %%
rocaucbinB = RocAucBinary()
learnB = tabular_learner(dlsB, metrics=[rocaucbinB, accuracy], emb_szs={'month':6})

# %%
# catdict = getcatdict(df, catcols)
# metadict = {}
# for (cat, classes) in catdict.items():
# 	metadict[cat] = {'mapped_cat': cat, 'classes_info': {clas: clas for clas in classes}}
# with open('bank_meta.json', 'w') as fp:
# 	json.dump(metadict, fp)

# %%
# metadict={"job": {"mapped_cat": "job", "classes_info": {"#na#": "#na#", "admin.": "admin.", "blue-collar": "blue-collar", "entrepreneur": "entrepreneur", "housemaid": "housemaid", "management": "management", "retired": "retired", "self-employed": "self-employed", "services": "services", "student": "student", "technician": "technician", "unemployed": "unemployed", "unknown": "unknown"}}, "marital": {"mapped_cat": "marital", "classes_info": {"#na#": "#na#", "divorced": "divorced", "married": "married", "single": "single", "unknown": "unknown"}}, "education": {"mapped_cat": "education", "classes_info": {"#na#": "#na#", "basic.4y": "basic.4y", "basic.6y": "basic.6y", "basic.9y": "basic.9y", "high.school": "high.school", "illiterate": "illiterate", "professional.course": "professional.course", "university.degree": "university.degree", "unknown": "unknown"}}, "default": {"mapped_cat": "default", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown"}}, "housing": {"mapped_cat": "housing", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown", "yes": "yes"}}, "loan": {"mapped_cat": "loan", "classes_info": {"#na#": "#na#", "no": "no", "unknown": "unknown", "yes": "yes"}}, "contact": {"mapped_cat": "contact", "classes_info": {"#na#": "#na#", "cellular": "cellular", "telephone": "telephone"}}, "month": {"mapped_cat": "month", "classes_info": {"#na#": "#na#", "apr": "apr", "aug": "aug", "dec": "dec", "jul": "jul", "jun": "jun", "mar": "mar", "may": "may", "nov": "nov", "oct": "oct", "sep":[]}}, "day_of_week": {"mapped_cat": "day_of_week", "classes_info": {"#na#": "#na#", "fri": "fri", "mon": "mon", "thu": "thu", "tue": "tue", "wed": "wed"}}, "poutcome": {"mapped_cat": "poutcome", "classes_info": {"#na#": "#na#", "failure": "failure", "nonexistent": "nonexistent", "success": "success"}}}

# %%
with open('../data/jsons/bank_meta.json', 'r') as fp:
    metadict = json.load(fp)

# %%
metadict
# Out:
# {'job': {'mapped_cat': 'job',
#   'classes_info': {'#na#': '#na#',
#    'admin.': 'admin.',
#    'blue-collar': 'blue-collar',
#    'entrepreneur': 'entrepreneur',
#    'housemaid': 'housemaid',
#    'management': 'management',
#    'retired': 'retired',
#    'self-employed': 'self-employed',
#    'services': 'services',
#    'student': 'student',
#    'technician': 'technician',
#    'unemployed': 'unemployed',
#    'unknown': 'unknown'}},
#  'marital': {'mapped_cat': 'marital',
#   'classes_info': {'#na#': '#na#',
#    'divorced': 'divorced',
#    'married': 'married',
#    'single': 'single',
#    'unknown': 'unknown'}},
#  'education': {'mapped_cat': 'education',
#   'classes_info': {'#na#': '#na#',
#    'basic.4y': 'basic.4y',
#    'basic.6y': 'basic.6y',
#    'basic.9y': 'basic.9y',
#    'high.school': 'high.school',
#    'illiterate': 'illiterate',
#    'professional.course': 'professional.course',
#    'university.degree': 'university.degree',
#    'unknown': 'unknown'}},
#  'default': {'mapped_cat': 'default',
#   'classes_info': {'#na#': '#na#', 'no': 'no', 'unknown': 'unknown'}},
#  'housing': {'mapped_cat': 'housing',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'loan': {'mapped_cat': 'loan',
#   'classes_info': {'#na#': '#na#',
#    'no': 'no',
#    'unknown': 'unknown',
#    'yes': 'yes'}},
#  'contact': {'mapped_cat': 'contact',
#   'classes_info': {'#na#': '#na#',
#    'cellular': 'cellular',
#    'telephone': 'telephone'}},
#  'month': {'mapped_cat': 'month',
#   'classes_info': {'#na#': '#na#',
#    'apr': 'apr',
#    'aug': 'aug',
#    'dec': 'dec',
#    'jul': 'jul',
#    'jun': 'jun',
#    'mar': 'mar',
#    'may': 'may',
#    'nov': 'nov',
#    'oct': 'oct',
#    'sep': []}},
#  'day_of_week': {'mapped_cat': 'day_of_week',
#   'classes_info': {'#na#': '#na#',
#    'fri': 'fri',
#    'mon': 'mon',
#    'thu': 'thu',
#    'tue': 'tue',
#    'wed': 'wed'}},
#  'poutcome': {'mapped_cat': 'poutcome',
#   'classes_info': {'#na#': '#na#',
#    'failure': 'failure',
#    'nonexistent': 'nonexistent',
#    'success': 'success'}}}

# %%
learnB.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown']

# %%
learnA.dls.categorify['default']
# Out:
# ['#na#', 'no', 'unknown', 'yes']

# %%
learnA.model.embeds
# Out:
# ModuleList(
#   (0): Embedding(13, 7)
#   (1): Embedding(5, 4)
#   (2): Embedding(9, 5)
#   (3): Embedding(4, 3)
#   (4): Embedding(4, 3)
#   (5): Embedding(4, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(10, 6)
#   (8): Embedding(6, 4)
#   (9): Embedding(4, 3)
# )

# %%
learnB.model.embeds
# Out:
# ModuleList(
#   (0): Embedding(13, 7)
#   (1): Embedding(5, 4)
#   (2): Embedding(9, 5)
#   (3): Embedding(3, 3)
#   (4): Embedding(4, 3)
#   (5): Embedding(4, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(11, 6)
#   (8): Embedding(6, 4)
#   (9): Embedding(4, 3)
# )

# %%
learnB.dls.cat_names
# Out:
# (#10) ['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']

# %%
transfercats = ['job',
 'marital',
 'education',
 'default',
 'housing',
 'loan',
 'contact',
 'month',
 'day_of_week',
 'poutcome']

# %%
catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcols}

# %%
# transfer_cats = (" workclass", " marital_status", " race", " relationship", " education")
# catcolsB = tuple(learnB.dls.cat_names)
# catdictB = {col:list(learnB.dls.categorify.classes[col]) for col in catcolsB}
transferembeds_(
    learnB.model.embeds, 
    learnA.model.embeds, 
    metadict, 
    transfercats, 
    newcatcols=catcols, 
    oldcatcols=catcols, 
    oldcatdict=catdictA, 
    newcatdict=catdictB)

# %%
learnA.model.embeds[catcols.index('marital')].weight
# Out:
# Parameter containing:
# tensor([[-0.0041,  0.0100,  0.0102, -0.0024],
#         [ 0.0009,  0.0190,  0.0418,  0.0202],
#         [-0.0319,  0.0140, -0.0415, -0.0403],
#         [ 0.0654, -0.0346, -0.0149,  0.0547],
#         [-0.0699, -0.0018, -0.0980,  0.0875]], requires_grad=True)

# %%
learnB.model.embeds[catcols.index('marital')].weight
# Out:
# Parameter containing:
# tensor([[-0.0041,  0.0100,  0.0102, -0.0024],
#         [ 0.0009,  0.0190,  0.0418,  0.0202],
#         [-0.0319,  0.0140, -0.0415, -0.0403],
#         [ 0.0654, -0.0346, -0.0149,  0.0547],
#         [-0.0699, -0.0018, -0.0980,  0.0875]], requires_grad=True)

# %%
dlsC = deepcopy(dlsB)
rocaucbinC = RocAucBinary()
learnC = tabular_learner(dlsC, metrics=[rocaucbinC, accuracy], emb_szs={'month':6})

# %%
learnC.model.layers.load_state_dict(learnB.model.layers.state_dict())
# Out:
# <All keys matched successfully>

# %%
for i in range(len(catcols)):
    learnB.model.embeds[i].weight.requires_grad = False
learnB.create_opt()

# %%
learnB.embeds[5].weight
# Out:
# Parameter containing:
# tensor([[ 0.0012, -0.0142, -0.0104],
#         [-0.0150,  0.0564, -0.0425],
#         [-0.0274,  0.0058, -0.0065],
#         [ 0.0386, -0.0425,  0.0627]])

# %%
cbsB=[WandbCallback(log="all", dataset_name="bank 0.3%", n_preds=128, seed=1)]
learnB.fit_one_cycle(3, cbs=cbsB)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/19 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.26% [1/19 00:00<00:01]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.53% [2/19 00:00<00:00 0.6940]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.79% [3/19 00:00<00:00 0.6697]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.05% [4/19 00:00<00:00 0.6713]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       26.32% [5/19 00:00<00:00 0.6690]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       47.37% [9/19 00:00<00:00 0.6427]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       73.68% [14/19 00:00<00:00 0.6116]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='19' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [19/19 00:00<00:00 0.5885]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [2/5 00:00<00:00 0.5831]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 00:00<00:00 0.5831]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:00<00:00 0.5831]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00 0.5831]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/19 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.26% [1/19 00:05<01:41]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.53% [2/19 00:05<00:48 0.5806]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.79% [3/19 00:05<00:30 0.5754]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.05% [4/19 00:05<00:21 0.5727]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       26.32% [5/19 00:05<00:15 0.5712]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       31.58% [6/19 00:05<00:12 0.5685]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.84% [7/19 00:05<00:09 0.5661]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       42.11% [8/19 00:05<00:07 0.5631]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       47.37% [9/19 00:05<00:06 0.5587]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.63% [10/19 00:05<00:05 0.5567]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 00:00<00:01]
#     </div>
#
# ...
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [2/5 00:00<00:00 0.5017]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 00:00<00:00 0.5017]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:00<00:00 0.5017]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00 0.5017]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 00:06<00:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.583056</td>
#       <td>0.652738</td>
#       <td>0.870181</td>
#       <td>0.725212</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.531010</td>
#       <td>0.522188</td>
#       <td>0.885025</td>
#       <td>0.811817</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.501736</td>
#       <td>0.498829</td>
#       <td>0.885407</td>
#       <td>0.809389</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(len(catcols)):
    learnB.model.embeds[i].weight.requires_grad = True
learnB.create_opt()

# %%
learnB.fit_one_cycle(5, cbs=cbsB)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/19 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.26% [1/19 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.53% [2/19 00:00<00:00 0.4447]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.79% [3/19 00:00<00:00 0.4356]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.05% [4/19 00:00<00:00 0.4431]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       26.32% [5/19 00:00<00:00 0.4512]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.63% [10/19 00:00<00:00 0.4561]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       89.47% [17/19 00:00<00:00 0.4670]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='19' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [19/19 00:00<00:00 0.4619]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [2/5 00:00<00:00 0.4616]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 00:00<00:00 0.4616]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:00<00:00 0.4616]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00 0.4616]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/19 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.26% [1/19 00:06<01:52]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.53% [2/19 00:06<00:53 0.4620]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.79% [3/19 00:06<00:33 0.4590]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.05% [4/19 00:06<00:23 0.4572]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       26.32% [5/19 00:06<00:18 0.4559]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       31.58% [6/19 00:06<00:14 0.4544]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.84% [7/19 00:06<00:11 0.4551]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       42.11% [8/19 00:06<00:09 0.4545]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       47.37% [9/19 00:06<00:07 0.4547]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='19' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.63% [10/19 00:06<00:06 0.4549]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:02]
#     </div>
# ...
#       80.00% [4/5 00:20<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:20<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [2/5 00:00<00:00 0.3944]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:20<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 00:00<00:00 0.3944]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:20<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:00<00:00 0.3944]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:20<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00<00:00 0.3944]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:20<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 00:20<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.461604</td>
#       <td>0.481070</td>
#       <td>0.882981</td>
#       <td>0.804533</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.449091</td>
#       <td>0.459576</td>
#       <td>0.882086</td>
#       <td>0.808580</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.429367</td>
#       <td>0.434223</td>
#       <td>0.885819</td>
#       <td>0.820316</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.409259</td>
#       <td>0.421703</td>
#       <td>0.887061</td>
#       <td>0.815864</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.394413</td>
#       <td>0.422471</td>
#       <td>0.887898</td>
#       <td>0.817887</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learnB.recorder.plot_loss()

# %%
wandb.finish()
