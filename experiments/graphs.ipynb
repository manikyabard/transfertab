# %%
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df = pd.read_csv('/Users/manikyabardhan/Documents/github/transfertab/data/exp/1c.csv')

# %%
df.head()
# Out:
#    Step  Group: Exp1a - train_loss  Group: Exp1a - train_loss__MIN  \
# 0     0                   0.847759                        0.803163
# 1     1                   0.834618                        0.793794
# 2     2                   0.826543                        0.791904
# 3     3                   0.813750                        0.783223
# 4     4                   0.807914                        0.773892
#
#    Group: Exp1a - train_loss__MAX
# 0                        0.892355
# 1                        0.875442
# 2                        0.861183
# 3                        0.844276
# 4                        0.841936

# %%
plt.figure(figsize=(10, 6))
# plt.plot(df['Step'], df['Group: Exp1a - train_loss'])
plt.plot(df['Step'], df['Group: Exp1a - train_loss__MAX'])
plt.plot(df['Step'], df['Group: Exp1a - train_loss__MIN'])

# %%
exp4 = pd.read_csv('/Users/manikyabardhan/Documents/github/transfertab/data/exp/4cv2.csv')

# %%
plt.figure(figsize=(20, 5))
# plt.plot(exp4['Step'], exp4['Group: Exp4c v2 - train_loss'], label='Model C')
plt.plot(exp4['Step'], exp4['Group: Exp4c v2 - train_loss__MAX'], label='Model C')
plt.plot(exp4['Step'], exp4['Group: Exp4c v2 - train_loss__MIN'], label='Model B')
plt.legend()

# %%
exp4['Group: Exp4c v2 - train_loss__MIN'][50:65]
# Out:
# 50    0.507524
# 51    0.506424
# 52    0.504524
# 53    0.502794
# 54    0.501825
# 55    0.502792
# 56    0.501736
# 57    0.519142
# 58    0.444714
# 59    0.435565
# 60    0.443122
# 61    0.451222
# 62    0.446267
# 63    0.454639
# 64    0.452596
# Name: Group: Exp4c v2 - train_loss__MIN, dtype: float64
